# %% [markdown]
# ## Example Running the PredictBitcoin10 model
#
# In this workbook, we will show you how to:-
# * Connect to the PredictBitcoin10 model do a batch transformation job
# * Create a model endpoint and call the model in real-time.
#
# The model has been created to perform real-time inference for bitcoin prediction.

# %%
import sagemaker
import os
import boto3
import sagemaker
import pandas as pd
import json

# %% [markdown]
# ### 1. Running a Batch Transformation
#
# The model runs pattern recognition to create features for this step; it requires >= 20160 rows of 1-minute weighted average tick data input data. When performing the batch transformation, we suggest using at least 60,000 data points of tick data that has been 1-minute weighted average tick data.

# %%
conn = boto3.client('s3')
my_bucket = 'cryptodatafiles'
my_file = 'dat1.csv'
s3client = boto3.client('s3')


data_location = 's3://cryptodatafiles/batch_test_2.csv'

payload = pd.read_csv(data_location)


payload.head(10)
# Out:
#        High      Open       Low     Close  Weighted_Price  Volume_BTC  \
# 0  11865.14  11865.14  11865.14  11865.14     11865.14000    0.000508
# 1  11865.14  11865.14  11854.20  11865.14     11864.77134    1.136199
# 2  11865.14  11865.14  11847.50  11850.73     11861.13916    0.110932
# 3  11853.71  11854.58  11852.23  11854.58     11852.65412    2.781860
# 4  11853.96  11861.10  11853.96  11861.10     11859.28307    1.339402
# 5  11849.01  11849.01  11838.49  11843.36     11840.21559    9.892109
# 6  11839.05  11839.05  11817.45  11834.27     11827.64002   16.112066
# 7  11835.24  11846.06  11835.24  11846.06     11841.03333    0.548520
# 8  11837.50  11837.50  11834.05  11834.05     11836.38969    0.246468
# 9  11836.74  11840.60  11836.20  11840.60     11836.66444    0.388882
#
#    Volume_Currency
# 0         6.030339
# 1     13480.737650
# 2      1315.776568
# 3     32972.420250
# 4     15884.341650
# 5    117124.698500
# 6    190567.722200
# 7      6495.039105
# 8      2917.294489
# 9      4603.066332

# %% [markdown]
# Below we create a model from the model package. Please remember to do this, you must **subscribe to BitcoinPredict10** and then change the **model_package_arn** to the specified one in your account.

# %%
# Please use the appropriate ARN obtained after subscribing to the model to define 'model_package_arn'
model_package_arn = 'arn:aws:sagemaker:eu-west-1:151286855433:model-package/bitcoinpredict10'

from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role

role = get_execution_role()
sagemaker_session = sage.Session()
model = ModelPackage(model_package_arn=model_package_arn,
                    role = role,
                    sagemaker_session = sagemaker_session)

# %% [markdown]
# In the below step, we create a batch transformation step. In building the model, we have used an m1.m5.large the model currently does not work on compute optimised instances.

# %%
# there is a limit of max 500 samples at a time for invoking endpoints
import json 
import uuid


transformer = model.transformer(1, 'ml.m5.large')
transformer.transform(data_location, content_type='text/csv')
transformer.wait()
#transformer.output_path
print("Batch Transform complete")
# Out:
# ............................Loading required package: xgboost
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:xgboost’:
#
#     slice
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: caret
# Loading required package: lattice
# Loading required package: ggplot2
# Loading required package: plumber
# Loading required package: earth
# Loading required package: Formula
# Loading required package: plotmo
# Loading required package: plotrix
# Loading required package: TeachingDemos
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ tibble  3.0.5     ✔ purrr   0.3.4
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ purrr::lift()   masks caret::lift()
# ✖ dplyr::slice()  masks xgboost::slice()
# Loading required package: jsonlite
#
# Attaching package: ‘jsonlite’
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
# Loading required package: Rlibeemd
# If you installed Rlibeemd from CRAN, consider installing again from GitHub if you wish to support for parallel computations: https://github.com/helske/Rlibeemd.
# Running plumber API at http://0.0.0.0:8080
# Running swagger Docs at http://127.0.0.1:8080/__docs__/
# Running plumber API at http://0.0.0.0:8080
# Running swagger Docs at http://127.0.0.1:8080/__docs__/
# 2021-03-01T22:15:02.901:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 2
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 3
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 2
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 3
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 4
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 5
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 4
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 5
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 6
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 7
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 8
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 6
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 7
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 8
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 9
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 10
# [1] 9
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 10
# [22:17:02] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 11
# [22:17:02] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 11
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 12
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 12
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 13
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 13
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
#
# Loading required package: xgboost
# Loading required package: dplyr
#
# Loading required package: xgboost
# Loading required package: dplyr
#
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:xgboost’:
#
#     slice
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: caret
# Loading required package: lattice
# Loading required package: ggplot2
# Loading required package: plumber
# Loading required package: earth
# Loading required package: Formula
# Loading required package: plotmo
# Loading required package: plotrix
# Loading required package: TeachingDemos
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ tibble  3.0.5     ✔ purrr   0.3.4
# Attaching package: ‘dplyr’
#
# The following object is masked from ‘package:xgboost’:
#
#     slice
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
# Loading required package: caret
# Loading required package: lattice
# Loading required package: ggplot2
# Loading required package: plumber
# Loading required package: earth
# Loading required package: Formula
# Loading required package: plotmo
# Loading required package: plotrix
# Loading required package: TeachingDemos
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Loading required package: tidyverse
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
# ✔ tibble  3.0.5     ✔ purrr   0.3.4
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ purrr::lift()   masks caret::lift()
# ✖ dplyr::slice()  masks xgboost::slice()
# Loading required package: jsonlite
#
# Attaching package: ‘jsonlite’
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
# Loading required package: Rlibeemd
# If you installed Rlibeemd from CRAN, consider installing again from GitHub if you wish to support for parallel computations: https://github.com/helske/Rlibeemd.
# ✔ tidyr   1.1.2     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.0
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ purrr::lift()   masks caret::lift()
# ✖ dplyr::slice()  masks xgboost::slice()
# Loading required package: jsonlite
#
# Attaching package: ‘jsonlite’
#
# The following object is masked from ‘package:purrr’:
#
#     flatten
#
# Loading required package: Rlibeemd
# If you installed Rlibeemd from CRAN, consider installing again from GitHub if you wish to support for parallel computations: https://github.com/helske/Rlibeemd.
# Running plumber API at http://0.0.0.0:8080
# Running swagger Docs at http://127.0.0.1:8080/__docs__/
# Running plumber API at http://0.0.0.0:8080
# Running swagger Docs at http://127.0.0.1:8080/__docs__/
# 2021-03-01T22:15:02.901:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 'data.frame':#01179659 obs. of  7 variables:
#  $ High           : num  11865 11865 11865 11854 11854 ...
#  $ Open           : num  11865 11865 11865 11855 11861 ...
#  $ Low            : num  11865 11854 11848 11852 11854 ...
#  $ Close          : num  11865 11865 11851 11855 11861 ...
#  $ Weighted_Price : num  11865 11865 11861 11853 11859 ...
#  $ Volume_BTC     : num  0.000508 1.136199 0.110932 2.78186 1.339402 ...
#  $ Volume_Currency: num  6.03 13480.74 1315.78 32972.42 15884.34 ...
# 'data.frame':#01179659 obs. of  7 variables:
#  $ High           : num  11865 11865 11865 11854 11854 ...
#  $ Open           : num  11865 11865 11865 11855 11861 ...
#  $ Low            : num  11865 11854 11848 11852 11854 ...
#  $ Close          : num  11865 11865 11851 11855 11861 ...
#  $ Weighted_Price : num  11865 11865 11861 11853 11859 ...
#  $ Volume_BTC     : num  0.000508 1.136199 0.110932 2.78186 1.339402 ...
#  $ Volume_Currency: num  6.03 13480.74 1315.78 32972.42 15884.34 ...
# [1] 1
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 1
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 2
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 3
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 2
# [22:16:58] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 3
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 4
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 5
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 4
# [22:16:59] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 5
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 6
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 7
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 8
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 6
# [22:17:00] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 7
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 8
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 9
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 10
# [1] 9
# [22:17:01] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 10
# [22:17:02] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 11
# [22:17:02] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 11
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 12
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 12
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 13
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [1] 13
# [22:17:03] WARNING: amalgamation/../src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# Batch Transform complete

# %% [markdown]
# Below we show the output of the batch transformation step. In this example, the early part of the model has overpredicted due to the dataset being too short as the model splits the batch data into equal 20160 datasets, with the earliest part allowed to be slightly shorter. Also, the model is autoregressive, which means it uses some of the earlier data points to predict future steps; therefore, please ignore the first 100 rows. The latter predictions will be within model tolerance.

# %%
import boto3
print(transformer.output_path)
bucketFolder = transformer.output_path.rsplit('/')[3]
bucket_name=transformer.output_path.rsplit('/')[2]

#print(s3bucket,s3prefix)
s3_conn = boto3.client("s3")
bucket_name="sagemaker-eu-west-1-151286855433"
with open('result.csv', 'wb') as f:
    s3_conn.download_fileobj(bucket_name,bucketFolder+'/batch_test_2.csv.out', f)
    print("Output file loaded from bucket")
# Out:
# s3://sagemaker-eu-west-1-151286855433/bitcoinpredict10-2021-03-01-22-08-17-944
# Output file loaded from bucket

# %%
df = pd.read_csv("result.csv")
df.head(10)
# Out:
# Empty DataFrame
# Columns: [[{"pred":12119.9337}, {"pred":12119.8138}, {"pred":12119.6938}, {"pred":12119.5737}, {"pred":12119.4535}, {"pred":12119.3332}, {"pred":12119.2128}, {"pred":12119.0922}, {"pred":12118.9716}, {"pred":12118.8508}, {"pred":12118.73}, {"pred":12118.609}, {"pred":12118.4879}, {"pred":12118.3667}, {"pred":12118.2454}, {"pred":12118.1239}, {"pred":12118.0024}, {"pred":12117.8807}, {"pred":12117.759}, {"pred":12117.6371}, {"pred":12117.5151}, {"pred":12117.393}, {"pred":12117.2708}, {"pred":12117.1485}, {"pred":12117.0261}, {"pred":12116.9035}, {"pred":12116.7809}, {"pred":12116.6581}, {"pred":12116.5353}, {"pred":12116.4123}, {"pred":12116.2892}, {"pred":12116.166}, {"pred":12116.0427}, {"pred":12115.9193}, {"pred":12115.7957}, {"pred":12115.6721}, {"pred":12115.5483}, {"pred":12115.4245}, {"pred":12115.3005}, {"pred":12115.1764}, {"pred":12115.0522}, {"pred":12114.9279}, {"pred":12114.8035}, {"pred":12114.679}, {"pred":12114.5543}, {"pred":12114.4296}, {"pred":12114.3047}, {"pred":12114.1798}, {"pred":12114.0547}, {"pred":12113.9295}, {"pred":12113.8042}, {"pred":12113.6788}, {"pred":12113.5533}, {"pred":12113.4277}, {"pred":12113.3019}, {"pred":12113.1761}, {"pred":12113.0501}, {"pred":12112.9241}, {"pred":12112.7979}, {"pred":12112.6716}, {"pred":12112.5452}, {"pred":12112.4187}, {"pred":12112.2921}, {"pred":12112.1654}, {"pred":12112.0385}, {"pred":12111.9116}, {"pred":12111.7845}, {"pred":12111.6574}, {"pred":12111.5301}, {"pred":12111.4027}, {"pred":12111.2752}, {"pred":12111.1476}, {"pred":12111.0199}, {"pred":12110.8921}, {"pred":12110.7642}, {"pred":12110.6361}, {"pred":12110.508}, {"pred":12110.3797}, {"pred":12110.2514}, {"pred":12110.1229}, {"pred":12109.9943}, {"pred":12109.8656}, {"pred":12109.7368}, {"pred":12109.6079}, {"pred":12109.4789}, {"pred":12109.3497}, {"pred":12109.2205}, {"pred":12109.0911}, {"pred":12108.9617}, {"pred":12108.8321}, {"pred":12108.7024}, {"pred":12108.5727}, {"pred":12108.4428}, {"pred":12108.3128}, {"pred":12108.1826}, {"pred":12108.0524}, {"pred":12107.9221}, {"pred":12107.7916}, {"pred":12107.6611}, {"pred":12107.5304}, ...]
# Index: []
#
# [0 rows x 79659 columns]

# %% [markdown]
# ###  2. Invoking endpoint

# %%
import json 
import uuid
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role
from sagemaker import ModelPackage
import boto3


role = get_execution_role()

sagemaker_session = sage.Session()
bucket=sagemaker_session.default_bucket()

# %% [markdown]
# In this step, we will create a model endpoint for prediction based on the model_pakage_arn. **We use exactly 20160 1 minute weighted tick data points** for real-time model predictions, which is approximately 2 weeks worth of exchange data. The data uses the same format as seen previously.

# %%
content_type='text/csv'
model_name='bitcoinpredict10'
real_time_inference_instance_type='ml.m5.large'

# %%
# Please use the appropriate ARN obtained after subscribing to the model to define 'model_package_arn'
model_package_arn = 'arn:aws:sagemaker:eu-west-1:151286855433:model-package/bitcoinpredict10'

# %%
from sagemaker import ModelPackage
import sagemaker as sage
from sagemaker import get_execution_role

role = get_execution_role()
sagemaker_session = sage.Session()

# %%
#Define predictor wrapper class
def predict_wrapper(endpoint, session):
    return sage.RealTimePredictor(endpoint, session,content_type=content_type)
#create a deployable model from the model package.
model = ModelPackage(role=role,
                    model_package_arn=model_package_arn,
                    sagemaker_session=sagemaker_session,
                    predictor_cls=predict_wrapper)

# %% [markdown]
# ### 1 a) Invoking endpoint via Python
#
# We create the model endpoint and deploy the model using Python code.

# %%
#create a deployable model from the model package.
model = ModelPackage(role=role,
                    model_package_arn=model_package_arn,
                    sagemaker_session=sagemaker_session)

#Deploy the model
predictor = model.deploy(1, real_time_inference_instance_type, endpoint_name=model_name)
# Out:
# -------------------!

# %% [markdown]
# We get the sample data which, as stated earlier, consists of 20160 rows.

# %%
conn = boto3.client('s3')
my_bucket = 'cryptodatafiles'
my_file = 'dat1.csv'
s3client = boto3.client('s3')

data_location = 's3://cryptodatafiles/dat1.csv'

payload = pd.read_csv(data_location)

payload=payload.to_csv(index=False)
train_file =data_location
m_endpoint = 'bitcoinpredict10'
runtime = boto3.Session().client('runtime.sagemaker')

# %% [markdown]
# In this step, we call the deployed model using the endpoint and get back the future 10-minute price based on the dataset.

# %%
# there is a limit of max 500 samples at a time for invoking endpoints

response = runtime.invoke_endpoint(EndpointName=m_endpoint,
                                   ContentType='text/csv',
                                   Body=payload)

result = json.loads(response['Body'].read().decode())
display(result)
# Out:
# [{'predicted': 11900.8349, '_row': '[20160,]'}]

# %% [markdown]
# ### 1 b) Invoking endpoint via AWS CLI
#
# Next, we show how the model can be called via AWS CLI.

# %%
file_name='dat1.csv'

model_name=  'bitcoinpredict10'

# %%
# !aws sagemaker-runtime invoke-endpoint \
    --endpoint-name 'bitcoinpredict10' \
    --body fileb://$file_name \
    --content-type 'text/csv' \
    --region eu-west-1 \
    $result.csv
# Out:
# An error occurred (ModelError) when calling the InvokeEndpoint operation: Received server error (500) from model with message "{"error":"500 - Internal server error"}". See https://eu-west-1.console.aws.amazon.com/cloudwatch/home?region=eu-west-1#logEventViewer:group=/aws/sagemaker/Endpoints/bitcoinpredict10 in account 151286855433 for more information.

# %% [markdown]
# ### Deleting Endpoints
# Finally, we delete the model endpoints as these are now not in use.

# %%
model.sagemaker_session.delete_endpoint(model_name)
model.sagemaker_session.delete_endpoint_config(model_name)

# %%
model.delete_model()
